# %%
from __future__ import print_function
__author__= 'fbb'

import pylab as pl
# this package sets up pretty plots
import seaborn
from scipy.optimize import curve_fit, minimize
    
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Chi Square Test

# %%
#distributions = ['pois', 'gaus', 'chisq', 'cauchy', 'lnorm', 'binomial']
distributions = ['chisq']

# %%
mymean =100
np.random.seed(445)
df=mymean

# %%
import numpy as np
md = {}
# md is an empty disctionary
md['chisq'] = np.random.chisquare(df, size=100)
# md now is a dictionary with one object: an array by the key 'chisq'
pl.hist(md['chisq'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')
pl.title("Chi Square Test", size = 12)
# Out:
# Text(0.5,1,'Chi Square Test')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Figure 1: Chi Square Test, df = 100, size = 100

# %%
print ("Chisq mean: %.2f, standard deviation: %.2f"%(md['chisq'].mean(), md['chisq'].std()))
# Out:
# Chisq mean: 97.56, standard deviation: 12.51

# %%
mysize=[]
for i in range(2,102):
    mysize.append(int((i*20.1)-29.8))
#mysize = (2000 / (np.array(rage(1, 100)))).astype(int)
# mysize = 1000 / (np.array(range(1, 100) + [10]))
# mysize = (np.random.rand(100) * 1000).astype(int)
print (mysize)
# Out:
# [10, 30, 50, 70, 90, 110, 131, 151, 171, 191, 211, 231, 251, 271, 291, 311, 332, 352, 372, 392, 412, 432, 452, 472, 492, 512, 533, 553, 573, 593, 613, 633, 653, 673, 693, 713, 734, 754, 774, 794, 814, 834, 854, 874, 894, 914, 935, 955, 975, 995, 1015, 1035, 1055, 1075, 1095, 1115, 1136, 1156, 1176, 1196, 1216, 1236, 1256, 1276, 1296, 1316, 1337, 1357, 1377, 1397, 1417, 1437, 1457, 1477, 1497, 1517, 1538, 1558, 1578, 1598, 1618, 1638, 1658, 1678, 1698, 1718, 1739, 1759, 1779, 1799, 1819, 1839, 1859, 1879, 1899, 1919, 1940, 1960, 1980, 2000]

# %%
md['chisq'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in mysize:
    md['chisq'][n] = np.random.chisquare(df, size = n)
    
# save the means for plotting later    

md['chisq']['means'] = {}
axchisq_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['chisq']:
    if not type(nn) == str:
        md['chisq']['means'][nn] = md['chisq'][nn].mean()
        #and plot it
        axchisq_mu_n.plot(nn, md['chisq']['means'][nn], 'o')
        axchisq_mu_n.set_xlabel('sample size', fontsize=18)
        axchisq_mu_n.set_ylabel('sample mean', fontsize=18)
        axchisq_mu_n.set_title('Chi squared distribution', fontsize=18)
        axchisq_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# As the number of observations increase, the data is regressed towards the mean

# %% [markdown]
# ## Figure 2: 100 Chi square distributions

# %%
allmeans = list(md['chisq']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel(r'Sample mean', fontsize = 18)
pl.ylabel(r'N', fontsize = 18)
pl.title(r'Histogram for all means', fontsize = 14)
# Out:
# Text(0.5,1,'Histogram for all means')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Figure 3: Histogram for all means
# As data As the number of observations increase, the mean of data is regressed towards 100

# %% [markdown]
# # Poisson Distribution

# %%
distributions = ['pois']

# %%
mymean =100
np.random.seed(100)
df=mymean

# %%
# md is an empty disctionary
md['pois'] = np.random.poisson(df, size=100)
['pois']
# md now is a dictionary with one object: an array by the key 'chisq'
pl.hist(md['pois'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')
pl.title(r'Poisson Distribution', fontsize = 14)
# Out:
# Text(0.5,1,'Poisson Distribution')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Figure 4: Poisson Distribution

# %%
print ("Poisson mean: %.2f, standard deviation: %.2f"%(md['pois'].mean(), md['pois'].std()))
# Out:
# Poisson mean: 99.09, standard deviation: 9.47

# %%
md['pois'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in mysize:
    md['pois'][n] = np.random.poisson(df, size = n)
    
# save the means for plotting later    

md['pois']['means'] = {}
axpois_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['pois']:
    if not type(nn) == str:
        md['pois']['means'][nn] = md['pois'][nn].mean()
        #and plot it
        axpois_mu_n.plot(nn, md['pois']['means'][nn], 'o')
        axpois_mu_n.set_xlabel('sample size', fontsize=18)
        axpois_mu_n.set_ylabel('sample mean', fontsize=18)
        axpois_mu_n.set_title('poisson distribution', fontsize=18)
        axpois_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Figure 5: Poisson Distribution for n = 100
# As the number of observations are increased the data is regressed towards the mean.

# %%
allmeans = list(md['pois']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('sample size', fontsize = 18)
pl.title('Histogram for all means')
# Out:
# Text(0.5,1,'Histogram for all means')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Figure 6: Histogram for all means

# %% [markdown]
# # Gaussian Normal Distribution

# %%
distributions = ['gauss']

# %%
mymean = 100

# %%
df = mymean

# %%
# md is an empty disctionary
md['gauss'] = np.random.normal(df, size=1000)
# md now is a dictionary with one object: an array by the key 'chisq'
pl.hist(md['gauss'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')
pl.title('Normal Distribution')
# Out:
# Text(0.5,1,'Normal Distribution')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Figure 7: Normal Distribution

# %%
print ("Normal mean: %.2f, standard deviation: %.2f"%(md['gauss'].mean(), md['gauss'].std()))
# Out:
# Normal mean: 99.90, standard deviation: 0.96

# %%
md['gauss'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in mysize:
    md['gauss'][n] = np.random.normal(df, size = n)
    
# save the means for plotting later    

md['gauss']['means'] = {}
axgauss_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['gauss']:
    if not type(nn) == str:
        md['gauss']['means'][nn] = md['gauss'][nn].mean()
        #and plot it
        axgauss_mu_n.plot(nn, md['gauss']['means'][nn], 'o')
        axgauss_mu_n.set_xlabel('sample size', fontsize=18)
        axgauss_mu_n.set_ylabel('sample mean', fontsize=18)
        axgauss_mu_n.set_title('Normal gaussian distribution', fontsize=18)
        axgauss_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Figure 8: 100 Normal Distributions

# %% [markdown]
# As the number of observations keep increasing, the data is regressed towards the mean.

# %%
allmeans = list(md['gauss']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
pl.title('Hitogram for Normal Distributions', fontsize = 18)
# Out:
# Text(0.5,1,'Hitogram for Normal Distributions')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Figure 9: Histogram for all means in Normal Distribution

# %%
distributions = ['binom']

# %%
mymean = 100

# %%
df = mymean

# %%
# md is an empty disctionary
md['binom'] = np.random.binomial(df,0.5, size=100)
# md now is a dictionary with one object: an array by the key 'chisq'
pl.hist(md['binom'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')
pl.title('Binomial Distributions', fontsize = 12)
# Out:
# Text(0.5,1,'Binomial Distributions')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Figure 10: Binomial distribution

# %%
print ("Binomial mean: %.2f, standard deviation: %.2f"%(md['binom'].mean(), md['binom'].std()))
# Out:
# Binomial mean: 49.41, standard deviation: 5.13

# %%
md['binom'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in mysize:
    md['binom'][n] = np.random.binomial(200,0.5, size = n)
    
# save the means for plotting later    

md['binom']['means'] = {}
axbinom_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['binom']:
    if not type(nn) == str:
        md['binom']['means'][nn] = md['binom'][nn].mean()
        #and plot it
        axbinom_mu_n.plot(nn, md['binom']['means'][nn], 'o')
        axbinom_mu_n.set_xlabel('sample size', fontsize=18)
        axbinom_mu_n.set_ylabel('sample mean', fontsize=18)
        axbinom_mu_n.set_title('Binomial Distributions for 100 observations', fontsize=18)
        axbinom_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Figure 11: 100 Binomial Distributions

# %% [markdown]
# As the number of observations keep on increasing, the data is regressed towards the mean.

# %%
allmeans = list(md['binom']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
pl.title('Histogram for Binomial Distributions', fontsize = 18)
# Out:
# Text(0.5,1,'Histogram for Binomial Distributions')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Figure 12: Histogram for Binomial Distributions

# %% [markdown]
# # Lognormal Distribution

# %%
distributions = ['lognormal']

# %%
mymean = 100

# %%
df = mymean

# %%
# md is an empty disctionary
md['lognormal'] = np.random.lognormal(4.10157,1,n)
# md now is a dictionary with one object: an array by the key 'chisq'
pl.hist(md['lognormal'], bins = 30)
pl.ylabel('N')
pl.xlabel('x')
pl.title('Lognormal Distribution', fontsize = 18)
# Out:
# Text(0.5,1,'Lognormal Distribution')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Figure 13: Lognormal Distribution

# %%
print ("Lognormal mean: %.2f, standard deviation: %.2f"%(md['lognormal'].mean(), md['lognormal'].std()))
# Out:
# Lognormal mean: 93.49, standard deviation: 114.14

# %%
md['lognormal'] = {} 

#and do it in a for loop. not pythonic, but easily readable

for n in mysize:
    md['lognormal'][n] = np.random.lognormal(4.10157,1,n)
    
# save the means for plotting later    

md['lognormal']['means'] = {}
axcauchy_mu_n = pl.figure(figsize=(10,6)).add_subplot(111)

for nn in md['lognormal']:
    if not type(nn) == str:
        md['lognormal']['means'][nn] = md['lognormal'][nn].mean()
        #and plot it
        axcauchy_mu_n.plot(nn, md['lognormal']['means'][nn], 'o')
        axcauchy_mu_n.set_xlabel('sample size', fontsize=18)
        axcauchy_mu_n.set_ylabel('sample mean', fontsize=18)
        axcauchy_mu_n.set_title('Lognormal  Distribution', fontsize=18)
        axcauchy_mu_n.plot([min(mysize), max(mysize)], [df, df], 'k')
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Figure 14: 100 Lognormal Distributions
# As the number of observations are being increased, the data is being regressed to the mean.

# %%
allmeans = list(md['lognormal']['means'].values())

pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
pl.title('Histogram for Lognormal Distributions')
# Out:
# Text(0.5,1,'Histogram for Lognormal Distributions')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Figure 15: Histogram for all observations in Lognormal Distribution

# %%
list_allmeans = []
for i in ['pois', 'gauss', 'chisq', 'binom', 'lognormal']:
    print(i)
    print(len(list(md[i]['means'].values())))
    list_allmeansTemp = list(md[i]['means'].values())
    list_allmeans= list_allmeans+ list_allmeansTemp
# Out:
# pois
# 100
# gauss
# 100
# chisq
# 100
# binom
# 100
# lognormal
# 100

# %%
md.keys()
# Out:
# dict_keys(['binom', 'pois', 'lognormal', 'gauss', 'chisq'])

# %%
len(list_allmeans)
# Out:
# 500

# %%
import pandas as pd
a=pd.DataFrame(data=mysize)

# %%
len(a[0].unique())
# Out:
# 100

# %%
pl.figure(figsize=(10, 10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)
pl.title('Histogram', fontsize = 18)
# Out:
# Text(0.5,1,'Histogram')
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Figure 16: Histogram for the means
