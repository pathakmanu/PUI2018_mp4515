# %% [markdown]
# # Imports (compatible for Python 2 and Python 3)

# %%
try:
    import urllib2 as ulib
except ImportError:
    import urllib3 as ulib

try:
    from StringIO import BytesIO as io
except ImportError:
    from io import BytesIO as io

try:
    from urllib import urlencode as urlencode
except ImportError:
    from urllib.parse import urlencode as urlencode
    
try:
    from urllib import urlopen as urlopen
except ImportError:
    from urllib.request import urlopen as urlopen
    
try:
    from urllib2 import HTTPError as HTTPError
except ImportError:
    from urllib.error import HTTPError as HTTPError

import pandas as pd
import ast

# %%
API_URL = 'https://fb55.carto.com:443/api/v2/sql?q=select * from fb55.citibike'
#API URL connects to Carto db and it runs certain queries.
def queryCartoDB(query, formatting = 'CSV', source = API_URL):
        
    
    data =urlencode({'format':formatting, 'q':query}).encode("utf-8")
    try:
        response = urlopen(source, data)
        return response.read()
    except HTTPError as e:
        raise (ValueError('\n'.join(ast.literal_eval(e.readline())['error'])))
        
def get_data(query):
    try:
        return pd.read_csv(io(queryCartoDB(query)), sep = ',')
    except ValueError as v:
        print (str(v))

# %%
query = '''SELECT * FROM fb55.citibike; '''
table1 = get_data(query)
table1.head(10)
# Out:
#    the_geom    start_station_name  the_geom_webmercator  field_1  \
# 0       NaN    E 20 St & Park Ave                   NaN      175
# 1       NaN      W 43 St & 10 Ave                   NaN     1159
# 2       NaN     E 6 St & Avenue B                   NaN     2827
# 3       NaN       E 12 St & 3 Ave                   NaN     4961
# 4       NaN       W 41 St & 8 Ave                   NaN     6156
# 5       NaN       5 Ave & E 29 St                   NaN     7433
# 6       NaN  Allen St & Hester St                   NaN     7779
# 7       NaN       E 39 St & 3 Ave                   NaN     8327
# 8       NaN      10 Ave & W 28 St                   NaN     9435
# 9       NaN        E 2 St & 2 Ave                   NaN    10472
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.987520          1090  2015-02-01 01:23:00+00
# 1               -73.994618           682  2015-02-01 10:55:00+00
# ...

# %%
query = '''SELECT * FROM fb55.citibike 
WHERE tripduration > 1000
LIMIT 5
'''
table1 = get_data(query)
table1.head(5)
# Out:
#    the_geom    start_station_name  the_geom_webmercator  field_1  \
# 0       NaN    E 20 St & Park Ave                   NaN      175
# 1       NaN  Allen St & Hester St                   NaN     7779
# 2       NaN      10 Ave & W 28 St                   NaN     9435
# 3       NaN    Broadway & W 36 St                   NaN    20481
# 4       NaN       8 Ave & W 31 St                   NaN    21285
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.987520          1090  2015-02-01 01:23:00+00
# 1               -73.991908          1217  2015-02-02 20:12:00+00
# 2               -74.001768          1475  2015-02-03 12:31:00+00
# 3               -73.987654          1001  2015-02-04 19:59:00+00
# 4               -73.994811          1618  2015-02-04 21:58:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-01 01:42:00+00               503         107
# 1  2015-02-02 20:32:00+00               361        7712
# ...

# %%
query = '''SELECT * FROM fb55.citibike
ORDER BY end_station_id DESC;'''
table2 = get_data(query)
table2.head(5)
# Out:
#    the_geom     start_station_name  the_geom_webmercator  field_1  \
# 0       NaN     Broadway & W 49 St                   NaN    21372
# 1       NaN         West Thames St                   NaN    44023
# 2       NaN        8 Ave & W 31 St                   NaN     6504
# 3       NaN  LaGuardia Pl & W 3 St                   NaN    44006
# 4       NaN       6 Ave & Canal St                   NaN     7733
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.984427          1823  2015-02-04 22:18:00+00
# 1               -74.017134            96  2015-02-07 17:14:00+00
# 2               -73.994811          1523  2015-02-01 23:56:00+00
# 3               -73.998102           868  2015-02-07 17:13:00+00
# 4               -74.005664           899  2015-02-02 19:47:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-04 22:48:00+00               173       21315
# 1  2015-02-07 17:15:00+00               363       44016
# ...

# %%
query = '''SELECT MIN(tripduration) as LOL FROM fb55.citibike
LIMIT 5
'''
table2 = get_data(query)
table2.head(5)
#we can name name right now
# Out:
#    lol  Unnamed: 1
# 0   60         NaN

# %%
query = '''SELECT * FROM fb55.citibike
ORDER BY start_station_id ASC, end_station_id DESC;'''
#if you have repeating values for the first one, then you can sort by the second one - so for start station you have 128 the same so then it will sort by end station desc
table3 = get_data(query)
table3.head(5)
# Out:
#    the_geom start_station_name  the_geom_webmercator  field_1  \
# 0       NaN   W 52 St & 11 Ave                   NaN    23585
# 1       NaN   W 52 St & 11 Ave                   NaN    14964
# 2       NaN   W 52 St & 11 Ave                   NaN      718
# 3       NaN   W 52 St & 11 Ave                   NaN    33255
# 4       NaN   W 52 St & 11 Ave                   NaN    23586
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.993929           432  2015-02-05 08:42:00+00
# 1               -73.993929           466  2015-02-04 09:47:00+00
# 2               -73.993929           344  2015-02-01 09:49:00+00
# 3               -73.993929           396  2015-02-06 09:59:00+00
# 4               -73.993929           424  2015-02-05 08:42:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-05 08:49:00+00                72       23546
# 1  2015-02-04 09:55:00+00                72       14920
# ...

# %% [markdown]
# ## TASK 1

# %%
query = '''SELECT * FROM fb55.citibike
WHERE tripduration <=10800
ORDER BY start_station_id ASC , tripduration ASC
LIMIT 10; '''
table4 = get_data(query)
table4
# Out:
#    the_geom start_station_name  the_geom_webmercator  field_1  \
# 0       NaN   W 52 St & 11 Ave                   NaN     9059
# 1       NaN   W 52 St & 11 Ave                   NaN    40772
# 2       NaN   W 52 St & 11 Ave                   NaN    40770
# 3       NaN   W 52 St & 11 Ave                   NaN    22002
# 4       NaN   W 52 St & 11 Ave                   NaN    43107
# 5       NaN   W 52 St & 11 Ave                   NaN    32603
# 6       NaN   W 52 St & 11 Ave                   NaN    16015
# 7       NaN   W 52 St & 11 Ave                   NaN    41366
# 8       NaN   W 52 St & 11 Ave                   NaN    42084
# 9       NaN   W 52 St & 11 Ave                   NaN     2348
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.993929           107  2015-02-03 10:10:00+00
# 1               -73.993929           189  2015-02-07 10:40:00+00
# 2               -73.993929           229  2015-02-07 10:40:00+00
# ...

# %%
query = '''SELECT DISTINCT start_station_id FROM fb55.citibike
WHERE tripduration <=10800
ORDER BY start_station_id DESC , tripduration DESC
LIMIT 10; '''
table4 = get_data(query)
table4.head(10)
# Out:
# Empty DataFrame
# Columns: [{"error":["for SELECT DISTINCT,  ORDER BY expressions must appear in select list"]}]
# Index: []

# %%
query = '''SELECT DISTINCT start_station_id FROM fb55.citibike
ORDER BY start_station_id
LIMIT 10
'''
table4 = get_data(query)
table4.head(10)
# Out:
#    start_station_id  Unnamed: 1
# 0                72         NaN
# 1                79         NaN
# 2                82         NaN
# 3                83         NaN
# 4               116         NaN
# 5               119         NaN
# 6               120         NaN
# 7               127         NaN
# 8               128         NaN
# 9               137         NaN

# %%
query = '''SELECT * FROM fb55.citibike
ORDER BY cartodb_id DESC
LIMIT 10 '''
table6 = get_data(query)
table6.head(10)
# Out:
#    the_geom     start_station_name  the_geom_webmercator  field_1  \
# 0       NaN         E 4 St & 2 Ave                   NaN    46199
# 1       NaN     Carmine St & 6 Ave                   NaN    46198
# 2       NaN        5 Ave & E 29 St                   NaN    46197
# 3       NaN        5 Ave & E 29 St                   NaN    46196
# 4       NaN        W 20 St & 8 Ave                   NaN    46195
# 5       NaN        1 Ave & E 44 St                   NaN    46194
# 6       NaN        E 20 St & 2 Ave                   NaN    46193
# 7       NaN  Warren St & Church St                   NaN    46192
# 8       NaN       W 47 St & 10 Ave                   NaN    46191
# 9       NaN        W 17 St & 8 Ave                   NaN    46190
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.989780           917  2015-02-07 23:59:00+00
# 1               -74.002150           548  2015-02-07 23:58:00+00
# ...

# %%
#query = '''SELECT DISTINCT birth_year FROM fb55.citibike
#WHERE birth_year IS NOT NULL; '''
#table7 = get_data(query)
#table7.head(5)

# %%
query = '''SELECT MIN(tripduration) as Min_TripDuration FROM fb55.citibike
WHERE tripduration IS NOT NULL; '''

table = get_data(query)
print(table)

query = '''SELECT MAX(tripduration) as Max_TripDuration FROM fb55.citibike
WHERE tripduration IS NOT NULL; '''

table = get_data(query)
print(table)

query = '''SELECT AVG(tripduration) FROM fb55.citibike
WHERE tripduration IS NOT NULL; '''

table = get_data(query)
print(table)
# Out:
#    min_tripduration  Unnamed: 1
# 0                60         NaN
#    max_tripduration  Unnamed: 1
# 0             43016         NaN
#           avg  Unnamed: 1
# 0  675.865823         NaN

# %%
query = ''' SELECT COUNT(tripduration) FROM fb55.citibike
 '''
table8 = get_data(query)
table8
# Out:
#    count  Unnamed: 1
# 0  46200         NaN

# %% [markdown]
# ## TASK 2

# %%
#query = '''SELECT * FROM fb55.citibike
#WHERE tripduration > 500; '''
#table9 = get_data(query)
#table9.head(6)

# %% [markdown]
# ### Getting 2nd feb data

# %%
query = '''SELECT * FROM fb55.citibike 
WHERE EXTRACT(DAY FROM starttime::date) = 2 '''
table10 = get_data(query)
table10.head()
# Out:
#    the_geom    start_station_name  the_geom_webmercator  field_1  \
# 0       NaN       5 Ave & E 29 St                   NaN     7433
# 1       NaN  Allen St & Hester St                   NaN     7779
# 2       NaN     E 5 St & Avenue C                   NaN       11
# 3       NaN       9 Ave & W 16 St                   NaN      627
# 4       NaN       9 Ave & W 16 St                   NaN      991
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.986831           376  2015-02-02 17:44:00+00
# 1               -73.991908          1217  2015-02-02 20:12:00+00
# 2               -73.979955          1312  2015-02-02 11:07:00+00
# 3               -74.004432           444  2015-02-02 00:40:00+00
# 4               -74.004432           438  2015-02-02 00:40:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-02 17:50:00+00               474        7367
# 1  2015-02-02 20:32:00+00               361        7712
# ...

# %% [markdown]
# ### weekend data

# %%
query = '''SELECT * FROM fb55.citibike AS asd
WHERE EXTRACT(DOW FROM starttime::date) IN (0,6) '''
table10 = get_data(query)
table10.head()
# Out:
#    the_geom  start_station_name  the_geom_webmercator  field_1  \
# 0       NaN  E 20 St & Park Ave                   NaN      175
# 1       NaN    W 43 St & 10 Ave                   NaN     1159
# 2       NaN   E 6 St & Avenue B                   NaN     2827
# 3       NaN     E 12 St & 3 Ave                   NaN     4961
# 4       NaN     W 41 St & 8 Ave                   NaN     6156
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.987520          1090  2015-02-01 01:23:00+00
# 1               -73.994618           682  2015-02-01 10:55:00+00
# 2               -73.981854           751  2015-02-01 13:59:00+00
# 3               -73.988900           272  2015-02-01 17:28:00+00
# 4               -73.990026           240  2015-02-01 21:36:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-01 01:42:00+00               503         107
# 1  2015-02-01 11:07:00+00               515        1088
# ...

# %% [markdown]
# ### weekend data

# %%
query = '''SELECT AVG(tripduration) FROM fb55.citibike
WHERE EXTRACT(DOW FROM starttime::date) IN (0,6); '''
 
table = get_data(query)
print(table)
# Out:
#           avg  Unnamed: 1
# 0  662.942181         NaN

# %% [markdown]
# ### weekday data

# %%
query = '''SELECT AVG(tripduration) FROM fb55.citibike
WHERE EXTRACT(DOW FROM starttime::date) NOT IN (0,6); '''
 
table = get_data(query)
print(table)
# Out:
#           avg  Unnamed: 1
# 0  681.052292         NaN

# %%
#query = '''SELECT starttime FROM fb55.citibike
#WHERE DAYOFWEEK(starttime::date) = "Monday"'''
#table11 = get_data(query)
#table11.head(6)

# %%
#query = '''SELECT starttime FROM fb55.citibike
#WHERE EXTRACT(HOUR FROM starttime::time) IN (0, 1, 2); '''
#table12 = get_data(query)
#table12.head(6)

# %%
#query = '''SELECT 2018-AVG(birth_year) FROM fb55.citibike
#WHERE EXTRACT(HOUR FROM starttime::time) = 2; '''
#table13 = get_data(query)
#table13.head(6)

# %% [markdown]
# ## Task 3

# %%
query = '''SELECT start_station_id, SUM(birth_year) as sum FROM fb55.citibike
GROUP BY start_station_id
ORDER BY sum DESC; '''
table14 = get_data(query)
table14.head(6)
# Out:
#    start_station_id      sum
# 0               521  1031381
# 1               435  1013377
# 2               293  1006381
# 3               477   986692
# 4               318   959496
# 5               497   888330

# %% [markdown]
# ### 0.0001 degrees = 11.1 m

# %%
query = '''SELECT start_station_name, SUM(tripduration) as sum FROM fb55.citibike
WHERE (start_station_longitude NOT BETWEEN 40.762 AND 40.753)
 AND
(start_station_latitude NOT BETWEEN -73.9755 AND -73.9845)
GROUP BY start_station_name
ORDER BY sum DESC
; '''
#group by something that is in the query. so couldn't group it by start_station_name
table15 = get_data(query)
table15.head(20)
# Out:
#           start_station_name     sum
# 0            8 Ave & W 31 St  359041
# 1            W 41 St & 8 Ave  330946
# 2   E 43 St & Vanderbilt Ave  320911
# 3         E 17 St & Broadway  314160
# 4            W 21 St & 6 Ave  307820
# 5      Lafayette St & E 8 St  290853
# 6            8 Ave & W 33 St  265748
# 7            W 31 St & 7 Ave  258912
# 8    Lexington Ave & E 24 St  246104
# 9            1 Ave & E 15 St  240803
# 10     Pershing Square North  239130
# 11           W 33 St & 7 Ave  236469
# 12        Broadway & E 22 St  236306
# 13     Pershing Square South  231590
# 14        E 14 St & Avenue B  230060
# 15           E 39 St & 2 Ave  226139
# 16        Broadway & E 14 St  221159
# 17           E 33 St & 2 Ave  219350
# 18  Elizabeth St & Hester St  219156
# 19        Broadway & W 24 St  217084

# %%
#query = '''SELECT start_station_name, AVG(tripduration) as average FROM fb55.citibike
#WHERE EXTRACT(HOUR FROM starttime::time) = 1
#GROUP BY start_station_name
#ORDER BY average ASC; '''
#table16 = get_data(query)
#table16.head(6)
# Out:
#        start_station_name  average
# 0  Fulton St & William St     77.0
# 1         9 Ave & W 16 St    120.0
# 2        W 56 St & 10 Ave    129.0
# 3         E 19 St & 3 Ave    155.0
# 4         W 13 St & 6 Ave    164.0
# 5    Peck Slip & Front St    176.0

# %%
#query = '''SELECT start_station_id FROM fb55.citibike
#WHERE (start_station_longitude NOT BETWEEN 40.762 AND 40.753)
 #AND
#(start_station_latitude NOT BETWEEN -73.9755 AND -73.9845)
#'''
# 
#table = get_data(query)
#print(table)

# %%
query = '''SELECT MAX(avg) FROM (SELECT AVG(tripduration) FROM fb55.citibike 
WHERE(EXTRACT(DOW FROM starttime::date) IN (0,6)) 
AND 
(start_station_longitude NOT BETWEEN 40.762 AND 40.753)
AND
(start_station_latitude NOT BETWEEN -73.9755 AND -73.9845)
GROUP BY start_station_name) AS max_avg
'''

table = get_data(query)
print(table)
# Out:
#         max  Unnamed: 1
# 0  1524.375         NaN
